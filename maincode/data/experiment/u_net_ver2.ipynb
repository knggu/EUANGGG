# %%
import matplotlib.pyplot as plt
import os
from scipy.io import wavfile
from collections import defaultdict, Counter
from scipy import signal
import numpy as np
import librosa
import random
import tensorflow as tf
from keras import models, layers

# %%
audio_data_path = r'C:./set1/train'

# %%
#파라미터 설정
sr = 16000
n_mfcc = 116
# n_ttf = 
# hop_length

# %%
trainset = []

# %%
label_mapping = {'belly_pain': 0, 'discomfort': 1, 'hungry': 2, 'tired': 3}

# %%
# 목표로 하는 패딩 크기
target_size = (116, 116)

# 폴더 내의 파일을 반복하여 데이터셋에 추가
for class_name in label_mapping.keys():
    class_path = os.path.join(audio_data_path, class_name)
    
    # 클래스 폴더 내의 WAV 파일에 대해 루프 수행
    for filename in os.listdir(class_path):
        if filename.endswith(".wav"):
            try:
                # WAV 파일 읽기
                wav_path = os.path.join(class_path, filename)
                wav, sr = librosa.load(wav_path, sr=None, mono=True, duration=5.0)
                
                # MFCC 추출
                mfcc = librosa.feature.mfcc(y=wav, sr=sr, n_mfcc=n_mfcc)
                
                # 패딩 또는 자르기 작업
                if mfcc.shape[1] > target_size[1]:
                    # 자르기
                    padded_mfcc = mfcc[:, :target_size[1]]
                else:
                    # 패딩
                    pad_width = target_size[1] - mfcc.shape[1]
                    padded_mfcc = np.pad(mfcc, ((0, 0), (0, pad_width)), mode='constant')
                
                # 라벨 할당
                label = label_mapping[class_name]
                
                # 데이터와 라벨을 trainset에 추가
                trainset.append((padded_mfcc, label))
                
            except Exception as e:
                print(f'Error processing {filename}: {e}')

# %%
# 패딩된 MFCC 배열 확인
for padded_mfcc, label in trainset:
    print(f'MFCC 크기: {padded_mfcc.shape}, 라벨: {label}')
# Out:
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 0
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 1
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 2
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3
# MFCC 크기: (116, 116), 라벨: 3

# %%
len(trainset)
# Out:
# 332

# %%
trainset[0][1]
# Out:
# 0

# %%
trainset_np = np.array(trainset, dtype=object)

# %%
trainset_np.shape
# Out:
# (332, 2)

# %%
from sklearn.model_selection import train_test_split

# trainset을 데이터와 라벨로 나누기
X = np.array([item[0] for item in trainset])
y = np.array([item[1] for item in trainset])

# 훈련 세트와 테스트 세트로 나누기 (예: 훈련 세트 80%, 테스트 세트 20%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2) #, random_state=1024

# 결과 확인
print(f"훈련 세트 크기: {X_train.shape}, 라벨 크기: {y_train.shape}")
print(f"테스트 세트 크기: {X_test.shape}, 라벨 크기: {y_test.shape}")
# Out:
# 훈련 세트 크기: (265, 116, 116), 라벨 크기: (265,)
# 테스트 세트 크기: (67, 116, 116), 라벨 크기: (67,)

# %%
# X_train의 차원을 (샘플 수, 98, 98, 1)로 조정
X_train_dim = X_train.reshape(X_train.shape + (1,))
X_test_dim = X_test.reshape(X_test.shape + (1,))

# %%
X_train_dim[0].shape
# Out:
# (116, 116, 1)

# %%
inputs = layers.Input(shape= X_train_dim[0].shape)



# Contracting path 시작
# [1]
conv0 = layers.Conv2D(8, activation='relu', kernel_size = 3)(inputs) # 116 - 114
conv1 = layers.Conv2D(8, activation='relu', kernel_size = 3)(conv0)  # Skip connection으로 Expanding path로 이어질 예정, 112
conv2 = layers.AveragePooling2D(pool_size=(2, 2), strides=(2, 2))(conv1) # 56


# [2]
conv3 = layers.Conv2D(16, activation='relu', kernel_size = 3)(conv2) # 56 - 54
conv4 = layers.Conv2D(16, activation='relu', kernel_size = 3)(conv3) # 52
conv5 = layers.AveragePooling2D(pool_size=(2, 2), strides=(2, 2))(conv4) #26


# [3]
conv6 = layers.Conv2D(32, activation='relu', kernel_size=3)(conv5) # 26 - 24
conv7 = layers.Conv2D(32, activation='relu', kernel_size=3)(conv6) # 22
# Contracting path 끝

# Expanding path 시작
# [6]
trans01 = layers.Conv2DTranspose(16, kernel_size=2, strides=(2, 2), activation='relu')(conv7) # 44
crop01 = layers.Cropping2D(cropping=(4, 4))(conv4) 
concat01 = layers.concatenate([trans01, crop01], axis=-1) # 44 & 52


# Q.위 이미지를 보고 [11]번 블럭을 구현해 봅시다. (filter 수를 주의하세요!)
conv8 = layers.Conv2D(16, activation='relu', kernel_size=3)(concat01) # 44 - 42
conv9 = layers.Conv2D(16, activation='relu', kernel_size=3)(conv8)  # 40
trans02 = layers.Conv2DTranspose(8, kernel_size=2, strides=(2, 2), activation='relu')(conv9)


# Q.위 이미지를 보고 [12]번 블럭을 구현해 봅시다. 
crop02 = layers.Cropping2D(cropping=(16, 16))(conv1) # 80 & 112
concat02 = layers.concatenate([trans02, crop02], axis=-1)


# [13]
conv10 = layers.Conv2D(8, activation='relu', kernel_size=3)(concat02) # 80 - 78 - 76
conv11 = layers.Conv2D(8, activation='relu', kernel_size=3)(conv10)
# Expanding path 끝

full01 = layers.Flatten()(conv11)
dense01 = layers.Dense(2048, activation='relu')(full01)
batch01 = layers.BatchNormalization()(dense01)
drop01 = layers.Dropout(0.3)(batch01)

dense02 = layers.Dense(512, activation='relu')(drop01)
batch02 = layers.BatchNormalization()(dense02)
drop02 = layers.Dropout(0.3)(dense02)



out_layer = layers.Dense(4, activation='softmax')(dense02)



model = tf.keras.Model(inputs=inputs, outputs=out_layer)



model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 116, 116, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 114, 114, 8)  80          ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 112, 112, 8)  584         ['conv2d[0][0]']
#
#  average_pooling2d (AveragePool  (None, 56, 56, 8)   0           ['conv2d_1[0][0]']
#  ing2D)
#
#  conv2d_2 (Conv2D)              (None, 54, 54, 16)   1168        ['average_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 52, 52, 16)   2320        ['conv2d_2[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 26, 26, 16)  0           ['conv2d_3[0][0]']
#  oling2D)
#
#  conv2d_4 (Conv2D)              (None, 24, 24, 32)   4640        ['average_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 22, 22, 32)   9248        ['conv2d_4[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 44, 44, 16)  2064        ['conv2d_5[0][0]']
#  ose)
#
#  cropping2d (Cropping2D)        (None, 44, 44, 16)   0           ['conv2d_3[0][0]']
#
#  concatenate (Concatenate)      (None, 44, 44, 32)   0           ['conv2d_transpose[0][0]',
#                                                                   'cropping2d[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 42, 42, 16)   4624        ['concatenate[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 40, 40, 16)   2320        ['conv2d_6[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 80, 80, 8)   520         ['conv2d_7[0][0]']
#  spose)
#
#  cropping2d_1 (Cropping2D)      (None, 80, 80, 8)    0           ['conv2d_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 80, 80, 16)   0           ['conv2d_transpose_1[0][0]',
#                                                                   'cropping2d_1[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 78, 78, 8)    1160        ['concatenate_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 76, 76, 8)    584         ['conv2d_8[0][0]']
#
#  flatten (Flatten)              (None, 46208)        0           ['conv2d_9[0][0]']
#
#  dense (Dense)                  (None, 2048)         94636032    ['flatten[0][0]']
#
#  batch_normalization (BatchNorm  (None, 2048)        8192        ['dense[0][0]']
#  alization)
#
#  dropout (Dropout)              (None, 2048)         0           ['batch_normalization[0][0]']
#
#  dense_1 (Dense)                (None, 512)          1049088     ['dropout[0][0]']
#
#  dense_2 (Dense)                (None, 4)            2052        ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 95,724,676
# Trainable params: 95,720,580
# Non-trainable params: 4,096
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train_dim, y_train, epochs=35, batch_size=16,  validation_data = (X_test_dim, y_test))
# Out:
# Epoch 1/35
# 17/17 [==============================] - 5s 83ms/step - loss: 2.6802 - accuracy: 0.3019 - val_loss: 43.5836 - val_accuracy: 0.1940
# Epoch 2/35
# 17/17 [==============================] - 1s 33ms/step - loss: 1.0696 - accuracy: 0.7245 - val_loss: 2.9840 - val_accuracy: 0.3433
# Epoch 3/35
# 17/17 [==============================] - 1s 32ms/step - loss: 0.1599 - accuracy: 0.9472 - val_loss: 3.2161 - val_accuracy: 0.3134
# Epoch 4/35
# 17/17 [==============================] - 1s 33ms/step - loss: 0.1289 - accuracy: 0.9585 - val_loss: 3.4456 - val_accuracy: 0.2687
# Epoch 5/35
# 17/17 [==============================] - 1s 32ms/step - loss: 0.1515 - accuracy: 0.9434 - val_loss: 1.9247 - val_accuracy: 0.4925
# Epoch 6/35
# 17/17 [==============================] - 1s 32ms/step - loss: 0.1283 - accuracy: 0.9774 - val_loss: 3.7292 - val_accuracy: 0.2985
# Epoch 7/35
# 17/17 [==============================] - 1s 33ms/step - loss: 0.1121 - accuracy: 0.9509 - val_loss: 1.9756 - val_accuracy: 0.4478
# Epoch 8/35
# 17/17 [==============================] - 1s 33ms/step - loss: 0.0754 - accuracy: 0.9736 - val_loss: 2.3730 - val_accuracy: 0.4478
# Epoch 9/35
# 17/17 [==============================] - 1s 33ms/step - loss: 0.0403 - accuracy: 0.9811 - val_loss: 2.5525 - val_accuracy: 0.5075
# Epoch 10/35
# 17/17 [==============================] - 1s 33ms/step - loss: 0.0401 - accuracy: 0.9887 - val_loss: 2.0093 - val_accuracy: 0.4776
# Epoch 11/35
# 17/17 [==============================] - 1s 32ms/step - loss: 0.0250 - accuracy: 0.9887 - val_loss: 3.1256 - val_accuracy: 0.3433
# Epoch 12/35
# 17/17 [==============================] - 1s 31ms/step - loss: 0.0456 - accuracy: 0.9811 - val_loss: 2.2646 - val_accuracy: 0.4030
# Epoch 13/35
# 17/17 [==============================] - 1s 31ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 2.2833 - val_accuracy: 0.4030
# Epoch 14/35
# 17/17 [==============================] - 1s 31ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 2.1810 - val_accuracy: 0.4179
# Epoch 15/35
# 17/17 [==============================] - 1s 32ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 2.1205 - val_accuracy: 0.4179
# Epoch 16/35
# 17/17 [==============================] - 1s 33ms/step - loss: 0.0183 - accuracy: 0.9925 - val_loss: 1.8289 - val_accuracy: 0.4478
# Epoch 17/35
# 17/17 [==============================] - 1s 32ms/step - loss: 0.0300 - accuracy: 0.9925 - val_loss: 1.9686 - val_accuracy: 0.4776
# Epoch 18/35
# 17/17 [==============================] - 1s 31ms/step - loss: 0.0211 - accuracy: 0.9962 - val_loss: 2.2023 - val_accuracy: 0.5075
# Epoch 19/35
# 17/17 [==============================] - 1s 32ms/step - loss: 0.0127 - accuracy: 0.9925 - val_loss: 2.2755 - val_accuracy: 0.4179
# Epoch 20/35
# 17/17 [==============================] - 1s 31ms/step - loss: 0.0590 - accuracy: 0.9925 - val_loss: 2.2561 - val_accuracy: 0.4776
# Epoch 21/35
# 17/17 [==============================] - 1s 32ms/step - loss: 0.0326 - accuracy: 0.9925 - val_loss: 2.5220 - val_accuracy: 0.5522
# Epoch 22/35
# 17/17 [==============================] - 1s 31ms/step - loss: 0.0305 - accuracy: 0.9925 - val_loss: 3.9920 - val_accuracy: 0.4179
# Epoch 23/35
# 17/17 [==============================] - 1s 32ms/step - loss: 0.0238 - accuracy: 0.9887 - val_loss: 4.0962 - val_accuracy: 0.4478
# Epoch 24/35
# 17/17 [==============================] - 1s 31ms/step - loss: 0.0291 - accuracy: 0.9887 - val_loss: 4.4684 - val_accuracy: 0.3284
# Epoch 25/35
# 17/17 [==============================] - 1s 33ms/step - loss: 0.0264 - accuracy: 0.9887 - val_loss: 4.1273 - val_accuracy: 0.4776
# Epoch 26/35
# 17/17 [==============================] - 1s 32ms/step - loss: 0.0593 - accuracy: 0.9849 - val_loss: 5.9271 - val_accuracy: 0.4478
# Epoch 27/35
# 17/17 [==============================] - 1s 31ms/step - loss: 0.0177 - accuracy: 0.9887 - val_loss: 4.7232 - val_accuracy: 0.4627
# Epoch 28/35
# 17/17 [==============================] - 1s 31ms/step - loss: 0.1057 - accuracy: 0.9660 - val_loss: 2.8351 - val_accuracy: 0.4030
# Epoch 29/35
# 17/17 [==============================] - 1s 32ms/step - loss: 0.1565 - accuracy: 0.9623 - val_loss: 3.5196 - val_accuracy: 0.5075
# Epoch 30/35
# 17/17 [==============================] - 1s 32ms/step - loss: 0.0305 - accuracy: 0.9887 - val_loss: 2.0550 - val_accuracy: 0.4328
# Epoch 31/35
# 17/17 [==============================] - 1s 31ms/step - loss: 0.0592 - accuracy: 0.9811 - val_loss: 2.4921 - val_accuracy: 0.5522
# Epoch 32/35
# 17/17 [==============================] - 1s 32ms/step - loss: 0.0866 - accuracy: 0.9698 - val_loss: 3.6115 - val_accuracy: 0.4627
# Epoch 33/35
# 17/17 [==============================] - 1s 32ms/step - loss: 0.0484 - accuracy: 0.9811 - val_loss: 3.6402 - val_accuracy: 0.3881
# Epoch 34/35
# 17/17 [==============================] - 1s 31ms/step - loss: 0.1660 - accuracy: 0.9660 - val_loss: 2.7014 - val_accuracy: 0.5075
# Epoch 35/35
# 17/17 [==============================] - 1s 31ms/step - loss: 0.1314 - accuracy: 0.9698 - val_loss: 5.0167 - val_accuracy: 0.3433

# %%
plt.style.use('seaborn-white')

history_dict = history.history

loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)
fig = plt.figure(figsize=(12, 5))

ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, 'b-', label='train_loss')
ax1.plot(epochs, val_loss, 'r-', label='val_loss')
ax1.set_title('Train and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.grid()
ax1.legend()

accuracy = history_dict['accuracy']
val_accuracy = history_dict['val_accuracy']

ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, accuracy, 'b-', label='train_accuracy')
ax2.plot(epochs, val_accuracy, 'r-', label='val_accuracy')
ax2.set_title('Train and Validation Accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.grid()
ax2.legend()

plt.show()
# Out:
# C:\Users\Desk_Kang\AppData\Local\Temp\ipykernel_12320\237002889.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-white')

# %%
model.evaluate(X_test_dim, y_test)
# Out:
# 3/3 [==============================] - 0s 7ms/step - loss: 5.0167 - accuracy: 0.3433
# [5.016720294952393, 0.34328359365463257]
