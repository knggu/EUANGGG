# %%
import pandas as pandas
import librosa
import numpy as np
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import librosa.display
import os
import matplotlib.pyplot as plt

# %%
#데이터 가져오기
data, sr = librosa.load('C:/Users/Desk_Kang/Desktop/Aiffel/workplace/lib/Aiffelthon/data1/hungry/hungry (3).wav')

# %%
hungry1 = librosa.display.waveshow(data, sr = sr)

# %%
ms1 = librosa.feature.melspectrogram(y=data, sr=sr)
log_ms1 = librosa.power_to_db(ms1, ref=np.max)
librosa.display.specshow(log_ms1, sr=sr, x_axis='time', y_axis='mel')

# %%
#데이터 가져오기
data1, sr1 = librosa.load('C:/Users/Desk_Kang/Desktop/Aiffel/workplace/lib/Aiffelthon/burping (4).wav')

# %%
burping1 = librosa.display.waveshow(data1, sr = sr1)

# %%
ms2 = librosa.feature.melspectrogram(y=data1, sr=sr1)
log_ms2 = librosa.power_to_db(ms2, ref=np.max)
librosa.display.specshow(log_ms2, sr=sr, x_axis='time', y_axis='mel')
