# %%
import matplotlib.pyplot as plt
import os
from scipy.io import wavfile
from collections import defaultdict, Counter
from scipy import signal
import numpy as np
import librosa
import random
import tensorflow as tf
from keras import models, layers

# %%
audio_data_path = r'C:./set1/train'

# %%
#파라미터 설정
sr = 16000
n_mels = 128
# n_ttf = 
# hop_length
# 224 222 220 110 108 106 54

# %%
trainset = []

# %%
label_mapping = {'belly_pain': 0, 'discomfort': 1, 'hungry': 2, 'tired': 3}

# %%
# 목표로 하는 패딩 크기
target_size = (n_mels, n_mels)

# 폴더 내의 파일을 반복하여 데이터셋에 추가
for class_name in label_mapping.keys():
    class_path = os.path.join(audio_data_path, class_name)
    
    # 클래스 폴더 내의 WAV 파일에 대해 루프 수행
    for filename in os.listdir(class_path):
        if filename.endswith(".wav"):
            try:
                # WAV 파일 읽기
                wav_path = os.path.join(class_path, filename)
                
                wav, sr = librosa.load(wav_path, sr=None, mono=True, duration=5.0)

                # Mel-spectrogram
                mels_spec = librosa.feature.melspectrogram(y=wav, sr= sr, n_mels= n_mels)
                
                # 패딩 또는 자르기 작업
                if mels_spec.shape[1] > target_size[1]:
                    # 자르기
                    padded_mels = mels_spec[:, :target_size[1]]
                else:
                    # 패딩
                    pad_width = target_size[1] - mels_spec.shape[1]
                    padded_mels = np.pad(mels_spec, ((0, 0), (0, pad_width)), mode='constant')
                
                # 라벨 할당
                label = label_mapping[class_name]
                
                # 데이터와 라벨을 trainset에 추가
                trainset.append((padded_mels, label))
                
            except Exception as e:
                print(f'Error processing {filename}: {e}')

# %%
# 패딩된 MFCC 배열 확인
for padded_mels, label in trainset:
    print(f'Mel_spec 크기: {padded_mels.shape}, 라벨: {label}')
# Out:
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 0
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 1
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 2
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3
# Mel_spec 크기: (128, 128), 라벨: 3

# %%
len(trainset)
# Out:
# 332

# %%
trainset[0][1]
# Out:
# 0

# %%
trainset_np = np.array(trainset, dtype=object)

# %%
trainset_np.shape
# Out:
# (332, 2)

# %%
from sklearn.model_selection import train_test_split

# trainset을 데이터와 라벨로 나누기
X = np.array([item[0] for item in trainset])
y = np.array([item[1] for item in trainset])

# 훈련 세트와 테스트 세트로 나누기 (예: 훈련 세트 80%, 테스트 세트 20%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2) #, random_state=1024

# 결과 확인
print(f"훈련 세트 크기: {X_train.shape}, 라벨 크기: {y_train.shape}")
print(f"테스트 세트 크기: {X_test.shape}, 라벨 크기: {y_test.shape}")
# Out:
# 훈련 세트 크기: (265, 128, 128), 라벨 크기: (265,)
# 테스트 세트 크기: (67, 128, 128), 라벨 크기: (67,)

# %%
# X_train의 차원을 (샘플 수, 98, 98, 1)로 조정
X_train_dim = X_train.reshape(X_train.shape + (1,))
X_test_dim = X_test.reshape(X_test.shape + (1,))

# %%
X_train_dim[0].shape
# Out:
# (128, 128, 1)

# %%
load_encoder = tf.keras.models.load_model('autoencoder_relu2.h5')

load_encoder.summary()
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 1)]     0
#
#  conv2d (Conv2D)             (None, 128, 128, 16)      160
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 16)      2320
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 16)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 32)        4640
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 64)        18496
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 64)        36928
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 128)       73856
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 128)       147584
#
# =================================================================
# Total params: 293,232
# Trainable params: 293,232
# Non-trainable params: 0
# _________________________________________________________________

# %%
freeze_layer = 9

# %%
for layer in load_encoder.layers[:freeze_layer]:
    layer.trainable = False

# %%
load_encoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 1)]     0
#
#  conv2d (Conv2D)             (None, 128, 128, 16)      160
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 16)      2320
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 16)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 32)        4640
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 64)        18496
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 64)        36928
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 128)       73856
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 128)       147584
#
# =================================================================
# Total params: 293,232
# Trainable params: 221,440
# Non-trainable params: 71,792
# _________________________________________________________________

# %%
inputs = layers.Input(shape= X_train_dim[0].shape)

input_layer = load_encoder(inputs)

# MSE -> input & output 비교
full01 = layers.Flatten()(input_layer)
dense01 = layers.Dense(512, activation='relu')(full01)
batch01 = layers.BatchNormalization()(dense01)
drop01 = layers.Dropout(0.25)(batch01)

dense02 = layers.Dense(128, activation='relu')(drop01)
batch02 = layers.BatchNormalization()(dense02)
drop02 = layers.Dropout(0.25)(dense02)



out_layer = layers.Dense(4, activation='softmax')(dense02)



model = tf.keras.Model(inputs=inputs, outputs=out_layer)



model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 1)]     0
#
#  model_1 (Functional)        (None, 16, 16, 128)       293232
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 512)               16777728
#
#  batch_normalization (BatchN  (None, 512)              2048
#  ormalization)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 128)               65664
#
#  dense_2 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 17,139,188
# Trainable params: 17,066,372
# Non-trainable params: 72,816
# _________________________________________________________________

# %%
# Compile and train your model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(X_train_dim, y_train, epochs=35,  validation_data = (X_test_dim, y_test))
# Out:
# Epoch 1/35
# 9/9 [==============================] - 3s 83ms/step - loss: 1.6633 - accuracy: 0.3887 - val_loss: 2.0745 - val_accuracy: 0.2836
# Epoch 2/35
# 9/9 [==============================] - 0s 16ms/step - loss: 1.0286 - accuracy: 0.5472 - val_loss: 2.1423 - val_accuracy: 0.2687
# Epoch 3/35
# 9/9 [==============================] - 0s 16ms/step - loss: 0.8413 - accuracy: 0.6679 - val_loss: 1.9303 - val_accuracy: 0.3433
# Epoch 4/35
# 9/9 [==============================] - 0s 16ms/step - loss: 0.7333 - accuracy: 0.7358 - val_loss: 1.7892 - val_accuracy: 0.3433
# Epoch 5/35
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6426 - accuracy: 0.7547 - val_loss: 1.7220 - val_accuracy: 0.3731
# Epoch 6/35
# 9/9 [==============================] - 0s 16ms/step - loss: 0.5246 - accuracy: 0.7962 - val_loss: 1.5695 - val_accuracy: 0.3433
# Epoch 7/35
# 9/9 [==============================] - 0s 16ms/step - loss: 0.4286 - accuracy: 0.8491 - val_loss: 1.5468 - val_accuracy: 0.3881
# Epoch 8/35
# 9/9 [==============================] - 0s 16ms/step - loss: 0.3937 - accuracy: 0.8679 - val_loss: 1.4579 - val_accuracy: 0.4030
# Epoch 9/35
# 9/9 [==============================] - 0s 16ms/step - loss: 0.3748 - accuracy: 0.8340 - val_loss: 1.3184 - val_accuracy: 0.4328
# Epoch 10/35
# 9/9 [==============================] - 0s 16ms/step - loss: 0.3079 - accuracy: 0.9057 - val_loss: 1.3973 - val_accuracy: 0.4925
# Epoch 11/35
# 9/9 [==============================] - 0s 16ms/step - loss: 0.3000 - accuracy: 0.9094 - val_loss: 1.3410 - val_accuracy: 0.4179
# Epoch 12/35
# 9/9 [==============================] - 0s 16ms/step - loss: 0.2475 - accuracy: 0.9283 - val_loss: 1.3417 - val_accuracy: 0.4478
# Epoch 13/35
# 9/9 [==============================] - 0s 16ms/step - loss: 0.2345 - accuracy: 0.9358 - val_loss: 1.3385 - val_accuracy: 0.4627
# Epoch 14/35
# 9/9 [==============================] - 0s 16ms/step - loss: 0.2434 - accuracy: 0.9245 - val_loss: 1.4315 - val_accuracy: 0.4179
# Epoch 15/35
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1829 - accuracy: 0.9283 - val_loss: 1.3396 - val_accuracy: 0.3881
# Epoch 16/35
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1557 - accuracy: 0.9660 - val_loss: 1.3016 - val_accuracy: 0.3582
# Epoch 17/35
# 9/9 [==============================] - 0s 16ms/step - loss: 0.1595 - accuracy: 0.9509 - val_loss: 1.3777 - val_accuracy: 0.4627
# Epoch 18/35
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0985 - accuracy: 0.9623 - val_loss: 1.4902 - val_accuracy: 0.4328
# Epoch 19/35
# 9/9 [==============================] - 0s 16ms/step - loss: 0.1124 - accuracy: 0.9585 - val_loss: 1.5384 - val_accuracy: 0.3433
# Epoch 20/35
# 9/9 [==============================] - 0s 16ms/step - loss: 0.1059 - accuracy: 0.9660 - val_loss: 1.5140 - val_accuracy: 0.3433
# Epoch 21/35
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0690 - accuracy: 0.9849 - val_loss: 1.5268 - val_accuracy: 0.3582
# Epoch 22/35
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0536 - accuracy: 0.9887 - val_loss: 1.5674 - val_accuracy: 0.3582
# Epoch 23/35
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0593 - accuracy: 0.9887 - val_loss: 1.5063 - val_accuracy: 0.4328
# Epoch 24/35
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0528 - accuracy: 0.9811 - val_loss: 1.4608 - val_accuracy: 0.4627
# Epoch 25/35
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0737 - accuracy: 0.9849 - val_loss: 1.4427 - val_accuracy: 0.4328
# Epoch 26/35
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0435 - accuracy: 0.9887 - val_loss: 1.4481 - val_accuracy: 0.4030
# Epoch 27/35
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0301 - accuracy: 0.9962 - val_loss: 1.4214 - val_accuracy: 0.4328
# Epoch 28/35
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0325 - accuracy: 0.9962 - val_loss: 1.4334 - val_accuracy: 0.4627
# Epoch 29/35
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0331 - accuracy: 0.9887 - val_loss: 1.4165 - val_accuracy: 0.4627
# Epoch 30/35
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0190 - accuracy: 0.9962 - val_loss: 1.4165 - val_accuracy: 0.4776
# Epoch 31/35
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0328 - accuracy: 0.9925 - val_loss: 1.5196 - val_accuracy: 0.4776
# Epoch 32/35
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0386 - accuracy: 0.9925 - val_loss: 1.5381 - val_accuracy: 0.4627
# Epoch 33/35
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0197 - accuracy: 0.9925 - val_loss: 1.5733 - val_accuracy: 0.4627
# Epoch 34/35
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0307 - accuracy: 0.9962 - val_loss: 1.5978 - val_accuracy: 0.4776
# Epoch 35/35
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0508 - accuracy: 0.9887 - val_loss: 1.5453 - val_accuracy: 0.4627

# %%
plt.style.use('seaborn-white')

history_dict = history.history

loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)
fig = plt.figure(figsize=(12, 5))

ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, 'b-', label='train_loss')
ax1.plot(epochs, val_loss, 'r-', label='val_loss')
ax1.set_title('Train and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.grid()
ax1.legend()

accuracy = history_dict['accuracy']
val_accuracy = history_dict['val_accuracy']

ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, accuracy, 'b-', label='train_accuracy')
ax2.plot(epochs, val_accuracy, 'r-', label='val_accuracy')
ax2.set_title('Train and Validation Accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.grid()
ax2.legend()

plt.show()
# Out:
# C:\Users\Desk_Kang\AppData\Local\Temp\ipykernel_808\237002889.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-white')
