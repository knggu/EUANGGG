# %%
import tensorflow as tf
import tensorflow_hub as hub
import csv
import io
import os
import glob
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tqdm import tqdm
import PIL
from PIL import Image
import librosa

# %%
temp_path = r"C:./dataset/spectrograms"
class_name = next(os.walk(temp_path))[1]

# %%
class_name
# Out:
# ['.ipynb_checkpoints',
#  'bellypain',
#  'burping',
#  'discomfort',
#  'hungry',
#  'tired',
#  'unlabeled']

# %%
labeled_fold_path = [os.path.join(temp_path, name) for name in class_name[1:6]]
labeled_fold_path
# Out:
# ['C:./dataset/spectrograms\\bellypain',
#  'C:./dataset/spectrograms\\burping',
#  'C:./dataset/spectrograms\\discomfort',
#  'C:./dataset/spectrograms\\hungry',
#  'C:./dataset/spectrograms\\tired']

# %%
lab_img_path = [glob.glob(os.path.join(folder,'*.png')) for folder in labeled_fold_path]
len(lab_img_path[0])
print(lab_img_path)
# Out:
# [['C:./dataset/spectrograms\\bellypain\\bellypain_spectrogram_1.png', 'C:./dataset/spectrograms\\bellypain\\bellypain_spectrogram_10.png', 'C:./dataset/spectrograms\\bellypain\\bellypain_spectrogram_11.png', 'C:./dataset/spectrograms\\bellypain\\bellypain_spectrogram_12.png', 'C:./dataset/spectrograms\\bellypain\\bellypain_spectrogram_13.png', 'C:./dataset/spectrograms\\bellypain\\bellypain_spectrogram_14.png', 'C:./dataset/spectrograms\\bellypain\\bellypain_spectrogram_15.png', 'C:./dataset/spectrograms\\bellypain\\bellypain_spectrogram_16.png', 'C:./dataset/spectrograms\\bellypain\\bellypain_spectrogram_2.png', 'C:./dataset/spectrograms\\bellypain\\bellypain_spectrogram_3.png', 'C:./dataset/spectrograms\\bellypain\\bellypain_spectrogram_4.png', 'C:./dataset/spectrograms\\bellypain\\bellypain_spectrogram_5.png', 'C:./dataset/spectrograms\\bellypain\\bellypain_spectrogram_6.png', 'C:./dataset/spectrograms\\bellypain\\bellypain_spectrogram_7.png', 'C:./dataset/spectrograms\\bellypain\\bellypain_spectrogram_8.png', 'C:./dataset/spectrograms\\bellypain\\bellypain_spectrogram_9.png'], ['C:./dataset/spectrograms\\burping\\burp_spectrogram_1.png', 'C:./dataset/spectrograms\\burping\\burp_spectrogram_2.png', 'C:./dataset/spectrograms\\burping\\burp_spectrogram_3.png', 'C:./dataset/spectrograms\\burping\\burp_spectrogram_4.png', 'C:./dataset/spectrograms\\burping\\burp_spectrogram_5.png', 'C:./dataset/spectrograms\\burping\\burp_spectrogram_6.png', 'C:./dataset/spectrograms\\burping\\burp_spectrogram_7.png', 'C:./dataset/spectrograms\\burping\\burp_spectrogram_8.png'], ['C:./dataset/spectrograms\\discomfort\\discomfort_spectrogram_1.png', 'C:./dataset/spectrograms\\discomfort\\discomfort_spectrogram_10.png', 'C:./dataset/spectrograms\\discomfort\\discomfort_spectrogram_11.png', 'C:./dataset/spectrograms\\discomfort\\discomfort_spectrogram_12.png', 'C:./dataset/spectrograms\\discomfort\\discomfort_spectrogram_13.png', 'C:./dataset/spectrograms\\discomfort\\discomfort_spectrogram_14.png', 'C:./dataset/spectrograms\\discomfort\\discomfort_spectrogram_15.png', 'C:./dataset/spectrograms\\discomfort\\discomfort_spectrogram_16.png', 'C:./dataset/spectrograms\\discomfort\\discomfort_spectrogram_17.png', 'C:./dataset/spectrograms\\discomfort\\discomfort_spectrogram_18.png', 'C:./dataset/spectrograms\\discomfort\\discomfort_spectrogram_19.png', 'C:./dataset/spectrograms\\discomfort\\discomfort_spectrogram_2.png', 'C:./dataset/spectrograms\\discomfort\\discomfort_spectrogram_20.png', 'C:./dataset/spectrograms\\discomfort\\discomfort_spectrogram_21.png', 'C:./dataset/spectrograms\\discomfort\\discomfort_spectrogram_22.png', 'C:./dataset/spectrograms\\discomfort\\discomfort_spectrogram_23.png', 'C:./dataset/spectrograms\\discomfort\\discomfort_spectrogram_24.png', 'C:./dataset/spectrograms\\discomfort\\discomfort_spectrogram_25.png', 'C:./dataset/spectrograms\\discomfort\\discomfort_spectrogram_26.png', 'C:./dataset/spectrograms\\discomfort\\discomfort_spectrogram_27.png', 'C:./dataset/spectrograms\\discomfort\\discomfort_spectrogram_3.png', 'C:./dataset/spectrograms\\discomfort\\discomfort_spectrogram_4.png', 'C:./dataset/spectrograms\\discomfort\\discomfort_spectrogram_5.png', 'C:./dataset/spectrograms\\discomfort\\discomfort_spectrogram_6.png', 'C:./dataset/spectrograms\\discomfort\\discomfort_spectrogram_7.png', 'C:./dataset/spectrograms\\discomfort\\discomfort_spectrogram_8.png', 'C:./dataset/spectrograms\\discomfort\\discomfort_spectrogram_9.png'], ['C:./dataset/spectrograms\\hungry\\hungry_spectrogram_1.png', 'C:./dataset/spectrograms\\hungry\\hungry_spectrogram_10.png', 'C:./dataset/spectrograms\\hungry\\hungry_spectrogram_100.png', 'C:./dataset/spectrograms\\hungry\\hungry_spectrogram_101.png', 'C:./dataset/spectrograms\\hungry\\hungry_spectrogram_102.png', 'C:./dataset/spectrograms\\hungry\\hungry_spectrogram_103.png', 'C:./dataset/spectrograms\\hungry\\hungry_spectrogram_104.png', 'C:./dataset/spectrograms\\hungry\\hungry_spectrogram_10 ...

# %%
unlab_foldpath = r"C:./dataset/spectrograms/unlabeled"
unlab_im_path = glob.glob(os.path.join(unlab_foldpath, '*.png'))
len(unlab_im_path)
# Out:
# 18190

# %%
def resize_and_normalize_image(image_path, new_size):
    with Image.open(image_path) as img:
        resized_image = img.resize(new_size).convert('RGB')
        image_array = np.array(resized_image)
        normalized_image = image_array / 255.0

    return normalized_image

# %%
# bellypain resize
bpain_img = [resize_and_normalize_image(path, (200, 100)) for path in lab_img_path[0]]
bpain_img_arr = np.array(bpain_img)

# %%
# burp resize
burp_img = [resize_and_normalize_image(path, (200, 100)) for path in lab_img_path[1]]
burp_img_arr = np.array(burp_img)

# %%
# discomfort resize
discomf_img = [resize_and_normalize_image(path, (200, 100)) for path in lab_img_path[2]]
discomf_img_arr = np.array(discomf_img)

# %%
# hungry resize
hgry_img = [resize_and_normalize_image(path, (200, 100)) for path in lab_img_path[3]]
hgry_img_arr = np.array(hgry_img)

# %%
# tired resize
tired_img = [resize_and_normalize_image(path, (200, 100)) for path in lab_img_path[4]]
tired_img_arr = np.array(tired_img)

# %%
# unlabeled resize
unlab_img = [resize_and_normalize_image(path, (200, 100)) for path in unlab_im_path]
unlab_img_arr = np.array(unlab_img)

# %%
print(bpain_img_arr.shape)
print(burp_img_arr.shape)
print(discomf_img_arr.shape)
print(hgry_img_arr.shape)
print(tired_img_arr.shape)
print(unlab_img_arr.shape)
# Out:
# (16, 100, 200, 3)
# (8, 100, 200, 3)
# (27, 100, 200, 3)
# (382, 100, 200, 3)
# (24, 100, 200, 3)
# (18190, 100, 200, 3)

# %%
from tensorflow.keras.applications.vgg16 import VGG16

model = VGG16(include_top=False, weights='imagenet', pooling='avg')

# Function to extract features from a 4D image array
def extract_features(img_array):
    # Ensure the image array is 4D (batch_size, height, width, channels)
    assert img_array.ndim == 4, "Input must be a 4D array"

    # Extract features
    features = model.predict(img_array)
    return features

# %%
# labeled data only
bpain_features = extract_features(bpain_img_arr)
burp_feature = extract_features(burp_img_arr)
discomf_feature = extract_features(discomf_img_arr)
hgry_feature = extract_features(hgry_img_arr)
tired_feature = extract_features(tired_img_arr)
# Out:
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 475ms/step
# 1/1 [==============================] - 1s 923ms/step
# 12/12 [==============================] - 2s 121ms/step
# 1/1 [==============================] - 1s 806ms/step

# %%
# unlabeled data feature extract
unlab_features = extract_features(unlab_img_arr)
# Out:
# 569/569 [==============================] - 23s 39ms/step

# %%
from sklearn.cluster import KMeans

features_by_class = {
    'bellypain': bpain_features,
    'burp': burp_feature,
    'discomfort': discomf_feature,
    'hungry': hgry_feature,
    'tired': tired_feature
}

centroids = {}

for class_label, features in features_by_class.items():
    kmeans = KMeans(n_clusters=1, random_state=0).fit(features)
    centroids[class_label] = kmeans.cluster_centers_[0]
# Out:
# C:\Users\dave\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\dave\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\dave\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\dave\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\dave\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
from scipy.spatial import distance

# Assuming centroids is a dictionary with class labels as keys and centroid vectors as values
# Assuming unlabeled_features is a list or array of feature vectors for unlabeled data

distances = {class_label: [] for class_label in centroids.keys()}

for i, feature_vector in enumerate(unlab_features):
    for class_label, centroid in centroids.items():
        dist = distance.euclidean(feature_vector, centroid)
        distances[class_label].append((i, dist))

# %%
similarities = {class_label: [] for class_label in centroids.keys()}

for i, feature_vector in enumerate(unlab_features):
    for class_label, centroid in centroids.items():
        similarity = 1 - distance.cosine(feature_vector, centroid)
        similarities[class_label].append((i, similarity))

# %%
import pandas as pd

# Initialize an empty list to store the data
data = []

# Iterate over each unlabeled data point
for i in range(len(unlab_features)):
    row = {}
    for class_label in centroids.keys():
        # Extracting distance and similarity for each class label
        distance = next(item for item in distances[class_label] if item[0] == i)[1]
        similarity = next(item for item in similarities[class_label] if item[0] == i)[1]

        # Creating column names and adding them to the row
        row[f'Distance_to_{class_label}'] = distance
        row[f'Similarity_to_{class_label}'] = similarity

    # Add the row to the data list
    data.append(row)

# Create the DataFrame
feat_sim_df = pd.DataFrame(data)

# %%
feat_sim_df
# Out:
#        Distance_to_bellypain  Similarity_to_bellypain  Distance_to_burp  \
# 0                   3.663705                 0.950008          3.798076
# 1                   4.095547                 0.938271          4.240916
# 2                   4.086757                 0.937741          4.200683
# 3                   3.986636                 0.940542          4.164264
# 4                   3.446669                 0.956050          3.588214
# ...                      ...                      ...               ...
# 18185               3.472385                 0.955549          3.684698
# 18186               3.977731                 0.941649          4.089080
# 18187               3.794546                 0.946202          3.959738
# 18188               4.119009                 0.936315          4.248916
# 18189               4.063064                 0.938466          4.264114
#
#        Similarity_to_burp  Distance_to_discomfort  Similarity_to_discomfort  \
# 0                0.946446                3.710215                  0.949197
# 1                0.933983                4.190486                  0.935860
# 2                0.934433                4.178236                  0.935513
# 3                0.935346                4.139020                  0.936523
# 4                0.952498                3.535270                  0.954132
# ...                   ...                     ...                       ...
# 18185            0.950074                3.683007                  0.950366
# 18186            0.938502                4.040771                  0.940248
# 18187            0.941613                3.932314                  0.942774
# 18188            0.932475                4.203336                  0.934344
# 18189            0.932443                4.228364                  0.933960
#
#        Distance_to_hungry  Similarity_to_hungry  Distance_to_tired  \
# 0                3.588126              0.952264           3.590718
# 1                4.065168              0.939407           4.040025
# 2                4.088264              0.937975           4.038696
# 3                3.999614              0.940440           3.952981
# 4                3.432418              0.956582           3.386961
# ...                   ...                   ...                ...
# 18185            3.524577              0.954368           3.447475
# 18186            3.958749              0.942422           3.908700
# 18187            3.819585              0.945747           3.761813
# 18188            4.132038              0.936231           4.069079
# 18189            4.102312              0.937553           4.053757
#
#        Similarity_to_tired
# 0                 0.952092
# 1                 0.940049
# 2                 0.939339
# 3                 0.941688
# 4                 0.957645
# ...                    ...
# 18185             0.956267
# 18186             0.943768
# 18187             0.947257
# 18188             0.938013
# 18189             0.938891
#
# [18190 rows x 10 columns]

# %%
dist_only_df = feat_sim_df[['Distance_to_bellypain', 'Distance_to_burp', 'Distance_to_discomfort', 'Distance_to_hungry', 'Distance_to_tired']]
dist_only_df
# Out:
#        Distance_to_bellypain  Distance_to_burp  Distance_to_discomfort  \
# 0                   3.663705          3.798076                3.710215
# 1                   4.095547          4.240916                4.190486
# 2                   4.086757          4.200683                4.178236
# 3                   3.986636          4.164264                4.139020
# 4                   3.446669          3.588214                3.535270
# ...                      ...               ...                     ...
# 18185               3.472385          3.684698                3.683007
# 18186               3.977731          4.089080                4.040771
# 18187               3.794546          3.959738                3.932314
# 18188               4.119009          4.248916                4.203336
# 18189               4.063064          4.264114                4.228364
#
#        Distance_to_hungry  Distance_to_tired
# 0                3.588126           3.590718
# 1                4.065168           4.040025
# 2                4.088264           4.038696
# 3                3.999614           3.952981
# 4                3.432418           3.386961
# ...                   ...                ...
# 18185            3.524577           3.447475
# 18186            3.958749           3.908700
# 18187            3.819585           3.761813
# 18188            4.132038           4.069079
# 18189            4.102312           4.053757
#
# [18190 rows x 5 columns]

# %%
sim_only_df = feat_sim_df[['Similarity_to_bellypain', 'Similarity_to_burp', 'Similarity_to_discomfort', 'Similarity_to_hungry', 'Similarity_to_tired']]
sim_only_df
# Out:
#        Similarity_to_bellypain  Similarity_to_burp  Similarity_to_discomfort  \
# 0                     0.950008            0.946446                  0.949197
# 1                     0.938271            0.933983                  0.935860
# 2                     0.937741            0.934433                  0.935513
# 3                     0.940542            0.935346                  0.936523
# 4                     0.956050            0.952498                  0.954132
# ...                        ...                 ...                       ...
# 18185                 0.955549            0.950074                  0.950366
# 18186                 0.941649            0.938502                  0.940248
# 18187                 0.946202            0.941613                  0.942774
# 18188                 0.936315            0.932475                  0.934344
# 18189                 0.938466            0.932443                  0.933960
#
#        Similarity_to_hungry  Similarity_to_tired
# 0                  0.952264             0.952092
# 1                  0.939407             0.940049
# 2                  0.937975             0.939339
# 3                  0.940440             0.941688
# 4                  0.956582             0.957645
# ...                     ...                  ...
# 18185              0.954368             0.956267
# 18186              0.942422             0.943768
# 18187              0.945747             0.947257
# 18188              0.936231             0.938013
# 18189              0.937553             0.938891
#
# [18190 rows x 5 columns]

# %%
dist_only_df.describe()
# Out:
#        Distance_to_bellypain  Distance_to_burp  Distance_to_discomfort  \
# count           18190.000000      18190.000000            18190.000000
# mean                3.798452          3.937073                3.913924
# std                 0.406094          0.411557                0.409031
# min                 1.726593          1.900339                1.771504
# 25%                 3.546027          3.679101                3.661476
# 50%                 3.818288          3.968929                3.954596
# 75%                 4.066256          4.206940                4.188848
# max                 5.549594          5.708679                5.531877
#
#        Distance_to_hungry  Distance_to_tired
# count        18190.000000       18190.000000
# mean             3.796752           3.759854
# std              0.412606           0.402381
# min              1.785135           1.738932
# 25%              3.539818           3.507643
# 50%              3.830903           3.789957
# 75%              4.072177           4.026163
# max              5.452256           5.445051

# %%
sim_only_df.describe()
# Out:
#        Similarity_to_bellypain  Similarity_to_burp  Similarity_to_discomfort  \
# count             18190.000000        18190.000000              18190.000000
# mean                  0.945736            0.941907                  0.942921
# std                   0.011156            0.011669                  0.011477
# min                   0.897705            0.893844                  0.897951
# 25%                   0.938513            0.934272                  0.935185
# 50%                   0.945553            0.941458                  0.942249
# 75%                   0.953200            0.949682                  0.950526
# max                   0.988851            0.986554                  0.988441
#
#        Similarity_to_hungry  Similarity_to_tired
# count          18190.000000         18190.000000
# mean               0.945998             0.946951
# std                0.011295             0.010931
# min                0.899397             0.901254
# 25%                0.938525             0.939793
# 50%                0.945517             0.946548
# 75%                0.953562             0.954255
# max                0.988164             0.988731

# %%
def inv_norm(column):
    return 1 - ((column - column.min()) / (column.max() - column.min()))

inv_norm_df = dist_only_df.apply(inv_norm)
inv_norm_df
# Out:
#        Distance_to_bellypain  Distance_to_burp  Distance_to_discomfort  \
# 0                   0.493301          0.501689                0.484436
# 1                   0.380342          0.385408                0.356718
# 2                   0.382641          0.395972                0.359975
# 3                   0.408830          0.405535                0.370404
# 4                   0.550072          0.556795                0.530960
# ...                      ...               ...                     ...
# 18185               0.543345          0.531460                0.491672
# 18186               0.411159          0.425277                0.396532
# 18187               0.459076          0.459240                0.425373
# 18188               0.374205          0.383307                0.353300
# 18189               0.388839          0.379316                0.346645
#
#        Distance_to_hungry  Distance_to_tired
# 0                0.508336           0.500344
# 1                0.378250           0.379110
# 2                0.371952           0.379468
# 3                0.396126           0.402596
# 4                0.550797           0.555322
# ...                   ...                ...
# 18185            0.525665           0.538994
# 18186            0.407270           0.414544
# 18187            0.445219           0.454178
# 18188            0.360015           0.371270
# 18189            0.368121           0.375405
#
# [18190 rows x 5 columns]

# %%
# row_variances = inv_only_df.var(axis=1)
# inv_norm_df['row_variance'] = row_variances

# %%
row_variances = sim_only_df.var(axis=1)
sim_only_df['row_variance'] = row_variances
# Out:
# C:\Users\dave\AppData\Local\Temp\ipykernel_25204\2922982619.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sim_only_df['row_variance'] = row_variances

# %%
sim_only_df
# Out:
#        Similarity_to_bellypain  Similarity_to_burp  Similarity_to_discomfort  \
# 0                     0.950008            0.946446                  0.949197
# 1                     0.938271            0.933983                  0.935860
# 2                     0.937741            0.934433                  0.935513
# 3                     0.940542            0.935346                  0.936523
# 4                     0.956050            0.952498                  0.954132
# ...                        ...                 ...                       ...
# 18185                 0.955549            0.950074                  0.950366
# 18186                 0.941649            0.938502                  0.940248
# 18187                 0.946202            0.941613                  0.942774
# 18188                 0.936315            0.932475                  0.934344
# 18189                 0.938466            0.932443                  0.933960
#
#        Similarity_to_hungry  Similarity_to_tired  row_variance
# 0                  0.952264             0.952092      0.000006
# 1                  0.939407             0.940049      0.000006
# 2                  0.937975             0.939339      0.000004
# 3                  0.940440             0.941688      0.000008
# 4                  0.956582             0.957645      0.000004
# ...                     ...                  ...           ...
# 18185              0.954368             0.956267      0.000009
# 18186              0.942422             0.943768      0.000004
# 18187              0.945747             0.947257      0.000006
# 18188              0.936231             0.938013      0.000005
# 18189              0.937553             0.938891      0.000008
#
# [18190 rows x 6 columns]

# %%
inv_norm_df
# Out:
#        Distance_to_bellypain  Distance_to_burp  Distance_to_discomfort  \
# 0                   0.493301          0.501689                0.484436
# 1                   0.380342          0.385408                0.356718
# 2                   0.382641          0.395972                0.359975
# 3                   0.408830          0.405535                0.370404
# 4                   0.550072          0.556795                0.530960
# ...                      ...               ...                     ...
# 18185               0.543345          0.531460                0.491672
# 18186               0.411159          0.425277                0.396532
# 18187               0.459076          0.459240                0.425373
# 18188               0.374205          0.383307                0.353300
# 18189               0.388839          0.379316                0.346645
#
#        Distance_to_hungry  Distance_to_tired
# 0                0.508336           0.500344
# 1                0.378250           0.379110
# 2                0.371952           0.379468
# 3                0.396126           0.402596
# 4                0.550797           0.555322
# ...                   ...                ...
# 18185            0.525665           0.538994
# 18186            0.407270           0.414544
# 18187            0.445219           0.454178
# 18188            0.360015           0.371270
# 18189            0.368121           0.375405
#
# [18190 rows x 5 columns]

# %%
sim_only_df.describe()
# Out:
#        Similarity_to_bellypain  Similarity_to_burp  Similarity_to_discomfort  \
# count             18190.000000        18190.000000              18190.000000
# mean                  0.945736            0.941907                  0.942921
# std                   0.011156            0.011669                  0.011477
# min                   0.897705            0.893844                  0.897951
# 25%                   0.938513            0.934272                  0.935185
# 50%                   0.945553            0.941458                  0.942249
# 75%                   0.953200            0.949682                  0.950526
# max                   0.988851            0.986554                  0.988441
#
#        Similarity_to_hungry  Similarity_to_tired  row_variance
# count          18190.000000         18190.000000  1.819000e+04
# mean               0.945998             0.946951  5.455249e-06
# std                0.011295             0.010931  1.964912e-06
# min                0.899397             0.901254  2.371310e-07
# 25%                0.938525             0.939793  4.092423e-06
# 50%                0.945517             0.946548  5.494172e-06
# 75%                0.953562             0.954255  6.818504e-06
# max                0.988164             0.988731  1.594601e-05

# %%
inv_norm_df.describe()
# Out:
#        Distance_to_bellypain  Distance_to_burp  Distance_to_discomfort  \
# count           18190.000000      18190.000000            18190.000000
# mean                0.458054          0.465191                0.430264
# std                 0.106224          0.108067                0.108774
# min                 0.000000          0.000000                0.000000
# 25%                 0.388004          0.394329                0.357153
# 50%                 0.452866          0.456826                0.419448
# 75%                 0.524082          0.532930                0.497398
# max                 1.000000          1.000000                1.000000
#
#        Distance_to_hungry  Distance_to_tired
# count        18190.000000       18190.000000
# mean             0.451445           0.454707
# std              0.112515           0.108572
# min              0.000000           0.000000
# 25%              0.376339           0.382850
# 50%              0.442132           0.446584
# 75%              0.521509           0.522759
# max              1.000000           1.000000

# %%
sim_final_df = sim_only_df.drop(columns = ['row_variance'], axis = 1)
dist_final_df = inv_norm_df.drop(columns = ['row_variance'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 2
#       1 sim_final_df = sim_only_df.drop(columns = ['row_variance'], axis = 1)
# ----> 2 dist_final_df = inv_norm_df.drop(columns = ['row_variance'], axis = 1)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:7000, in Index.drop(self, labels, errors)
#    6998 if mask.any():
#    6999     if errors != "ignore":
# -> 7000         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7001     indexer = indexer[~mask]
#    7002 return self.delete(indexer)
#
# KeyError: "['row_variance'] not found in axis"

# %%
sim_final_df.to_csv('cos_sim_cnnver.csv')
dist_final_df.to_csv('dist_cnnver.csv')
